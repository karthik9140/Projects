# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\karthik\OneDrive\Documents\Telco_Customer_Churn_Dataset .csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # Task 1 : Data Cleaning and Preproccesing

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df['MultipleLines'] = df['MultipleLines'].str.replace('No phone service','No')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1            No             DSL            Yes  ...              Yes
# 2            No             DSL            Yes  ...               No
# 3            No             DSL            Yes  ...              Yes
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df2 = 100*(df['Churn'].value_counts()/len(df['Churn']))
df2
# Out:
# No     73.463013
# Yes    26.536987
# Name: Churn, dtype: float64

# %%
#groping the tenure
labels = ["{0} - {1}".format(i,i+11) for i in range(1,72,12)]
df['tenure_group'] = pd.cut(df.tenure,range(1,80,12),right=False,labels = labels)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0              No            No             DSL             No  ...
# ...

# %% [markdown]
# # Task 2 : EDA

# %% [markdown]
# # Univariate analysis

# %%
df.drop(columns=['tenure','customerID'],inplace=True)
df
# Out:
#       gender  SeniorCitizen Partner Dependents PhoneService MultipleLines  \
# 0     Female              0     Yes         No           No            No
# 1       Male              0      No         No          Yes            No
# 2       Male              0      No         No          Yes            No
# 3       Male              0      No         No           No            No
# 4     Female              0      No         No          Yes            No
# ...      ...            ...     ...        ...          ...           ...
# 7038    Male              0     Yes        Yes          Yes           Yes
# 7039  Female              0     Yes        Yes          Yes           Yes
# 7040  Female              0     Yes        Yes           No            No
# 7041    Male              1     Yes         No          Yes           Yes
# 7042    Male              0      No         No          Yes            No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# ...

# %%
for i,predictor in enumerate(df.drop(columns=['Churn','TotalCharges','MonthlyCharges'])):
    plt.figure(i)
    sns.countplot(data=df,x=predictor,hue='Churn')

# %%
#converting churn to numeric value

# %%
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents PhoneService MultipleLines  \
# 0     Female              0     Yes         No           No            No
# 1       Male              0      No         No          Yes            No
# 2       Male              0      No         No          Yes            No
# 3       Male              0      No         No           No            No
# 4     Female              0      No         No          Yes            No
# ...      ...            ...     ...        ...          ...           ...
# 7038    Male              0     Yes        Yes          Yes           Yes
# 7039  Female              0     Yes        Yes          Yes           Yes
# 7040  Female              0     Yes        Yes           No            No
# 7041    Male              1     Yes         No          Yes           Yes
# 7042    Male              0      No         No          Yes            No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# ...

# %%
df_dummies = pd.get_dummies(df)
df_dummies
# Out:
#       SeniorCitizen  MonthlyCharges  Churn  gender_Female  gender_Male  \
# 0                 0           29.85      0              1            0
# 1                 0           56.95      0              0            1
# 2                 0           53.85      1              0            1
# 3                 0           42.30      0              0            1
# 4                 0           70.70      1              1            0
# ...             ...             ...    ...            ...          ...
# 7038              0           84.80      0              0            1
# 7039              0          103.20      0              1            0
# 7040              0           29.60      0              1            0
# 7041              1           74.40      1              0            1
# 7042              0          105.65      0              0            1
#
#       Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  PhoneService_No  \
# ...

# %%
Mth = sns.kdeplot(df_dummies.MonthlyCharges[(df_dummies['Churn']==0)],color='Red',shade=True)
Mth = sns.kdeplot(df_dummies.MonthlyCharges[df_dummies['Churn']==1],color='Blue',shade=True)
Mth.legend(['churn','no churn'])
Mth.set_ylabel('Density')
Mth.set_xlabel('Monthly Charges')
Mth.set_title('Monthly Charges by churn')
# Out:
# C:\Users\karthik\AppData\Local\Temp\ipykernel_17896\1073069581.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth = sns.kdeplot(df_dummies.MonthlyCharges[(df_dummies['Churn']==0)],color='Red',shade=True)
# C:\Users\karthik\AppData\Local\Temp\ipykernel_17896\1073069581.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth = sns.kdeplot(df_dummies.MonthlyCharges[df_dummies['Churn']==1],color='Blue',shade=True)
# Text(0.5, 1.0, 'Monthly Charges by churn')

# %% [markdown]
# # Bivariate Analysis

# %%
target1 = df.loc[df['Churn']==0]
target2 = df.loc[df['Churn']==1]

# %%
def uniplot(df, col, title, hue=None):
    sns.set_style('whitegrid')
    sns.set_context('talk')
    plt.rcParams["axes.labelsize"] = 20
    plt.rcParams['axes.titlesize'] = 22
    plt.rcParams['axes.titlepad'] = 30
    
    temp = pd.Series(data=hue)
    fig, ax = plt.subplots()
    width = len(df[col].unique()) + 7 + 4 * len(temp.unique())
    fig.set_size_inches(width, 8)
    plt.xticks(rotation=45)
    plt.yscale('log')
    plt.title(title)
    
    ax = sns.countplot(data=df, x=col, order=df[col].value_counts().index, hue=hue, palette='bright')
    
    plt.show()

# %%
uniplot(target2,col='Partner',title='Distribution of gender churned customer',hue='gender')

# %%
uniplot(target2,col='Dependents',title='Distribution of gender churned customer',hue='gender')

# %%
uniplot(target2,col='InternetService',title='Distribution of gender churned customer',hue='gender')

# %%
uniplot(target2,col='OnlineBackup',title='Distribution of gender churned customer',hue='gender')

# %% [markdown]
# The insights that we got are:
#
# 1 electronic check medium
# 2 monthly customer
# 3 Fiber Optic

# %%
df_dummies.to_csv('tel_churn.csv')

# %%
updated_df = pd.read_csv('tel_churn.csv')

# %%
updated_df.head()
# Out:
#    Unnamed: 0  SeniorCitizen  MonthlyCharges  Churn  gender_Female  \
# 0           0              0           29.85      0              1
# 1           1              0           56.95      0              0
# 2           2              0           53.85      1              0
# 3           3              0           42.30      0              0
# 4           4              0           70.70      1              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    TotalCharges_998.1  TotalCharges_999.45  TotalCharges_999.8  \
# ...
